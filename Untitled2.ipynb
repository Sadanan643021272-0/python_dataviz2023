# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadanan643021272-0/python_dataviz2023/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##วิธีหาเปิด csv file
# หาจากคำว่าเราต้องการอะไร ตามด้วย Python

# %%
###หาโค้ดในเน็ต

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx')
region= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=1)
result_constituancies_Partylist= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=2)
result_constituancies_Candidate = pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=3)
result_constituancies_Status= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=4)
info_province= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=5)
info_party_overview= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=6)
info_constituancy= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=7)
Candidate_constituancy= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=8)
Candidate_Partylist= pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=9)
Candidate_PM = pd.read_excel('/content/drive/MyDrive/DataViz23Data/ของหมู.xlsx',sheet_name=10)

# %%
result_constituancies_Status
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %%
creditcard = pd.read_csv('/content/drive/MyDrive/DataViz23Data/Data-Viz-2023-2/ซ้อม/Copy of creditcard_2023.csv')#id จะกลายเป็นIndex
creditcard
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
result_constituancies_Candidate.describe()
# Out:
#            party_id  party_list_vote  party_list_vote_percent
# count  26800.000000     26800.000000             26800.000000
# mean     742.955224      1380.483134                 1.478642
# std       25.123113      6089.388093                 8.655481
# min      701.000000         0.000000                 0.000000
# 25%      722.000000        21.000000                 0.021550
# 50%      741.000000        68.000000                 0.070730
# 75%      767.000000       215.000000                 0.220737
# max      786.000000     83851.000000               711.247710

# %%
result_constituancies_Candidate[result_constituancies_Candidate['mp_app_vote_percent']>100]
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 2593   NST_6   NST_6_1            5         5596            146.37719
# 2594   NST_6  NST_6_10            4         7731            202.22338
# 2601   NST_6   NST_6_4            6         5574            145.80173
# 2602   NST_6   NST_6_5            1        27331            714.90976
# 2605   NST_6   NST_6_8            3        10700            279.88491
# 2606   NST_6   NST_6_9            2        23260            608.42270
#
#       party_id
# 2593       705
# 2594       763
# 2601       701
# 2602       743
# 2605       726
# 2606       709

# %% [markdown]
# ##วิธีเช็คค่าNull

# %%
info_party_overview.isnull().any()#isnull ทำให้เป็นTrue or false
# Out:
# province_id              False
# prov_id                  False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations      False
# region_id                False
# dtype: bool

# %% [markdown]
# ##วิธี fillna

# %%
Fill_na_sasa = info_party_overview.fillna('99')
Fill_na_sasa
# Out:
#      id party_no           name    abbr    color  \
# 0   701     26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702     63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703     60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705     29.0       เพื่อไทย     พท.  #da3731
# 4   706     14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...      ...            ...     ...      ...
# 65  780     55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781      9.0           พลัง      พ.  #8e8fc7
# 67  783     52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784     23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786     20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %%
Fill_na_sasa[Fill_na_sasa ['party_no'] == '99']#เช็คว่าfillแล้ว
# Out:
#      id party_no          name  abbr    color  \
# 9   711       99  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       99     พลังบูรพา   พบ.  #4696d6
# 17  720       99     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# ##วิธีการ Merge and join

# %%
Con_id1=result_constituancies_Candidate[result_constituancies_Candidate['cons_id']=='ACR_1']

# %%
Con_id2 =result_constituancies_Candidate[result_constituancies_Candidate['cons_id']=='ACR_2']

# %%
Con_id3=result_constituancies_Candidate[result_constituancies_Candidate['cons_id']=='AYA_1']

# %%
Con_id1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
Con_id2
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 13   ACR_2   ACR_2_1            2        19188             17.16080       726
# 14   ACR_2  ACR_2_10            1        46881             41.92804       709
# 15   ACR_2  ACR_2_11           11          193              0.17261       742
# 16   ACR_2  ACR_2_12           12          173              0.15472       770
# 17   ACR_2   ACR_2_2            6         2027              1.81285       762
# 18   ACR_2   ACR_2_3            3        17637             15.77366       705
# 19   ACR_2   ACR_2_4           10          197              0.17619       712
# 20   ACR_2   ACR_2_5            5         2530              2.26271       701
# 21   ACR_2   ACR_2_6            8          519              0.46417       719
# 22   ACR_2   ACR_2_7            7         1156              1.03387       763
# 23   ACR_2   ACR_2_8            9          378              0.33806       769
# ...

# %%
Con_id3
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 42   AYA_1   AYA_1_1            6         1014              0.91917       701
# 43   AYA_1  AYA_1_10           10           98              0.08883       738
# 44   AYA_1   AYA_1_2            4         6677              6.05256       763
# 45   AYA_1   AYA_1_3            8          621              0.56292       762
# 46   AYA_1   AYA_1_4            9          364              0.32996       769
# 47   AYA_1   AYA_1_5            3        15289             13.85915       705
# 48   AYA_1   AYA_1_6            5         1250              1.13310       743
# 49   AYA_1   AYA_1_7            1        41081             37.23905       726
# 50   AYA_1   AYA_1_8            2        35676             32.33953       709
# 51   AYA_1   AYA_1_9            7          751              0.68077       719

# %%
consult = pd.concat([Con_id1,Con_id2])
consult
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
Candidate_constituancy
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4777   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url
# 0     https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
Con_id3.merge(Candidate_constituancy, on='mp_app_id', how='left')
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   AYA_1   AYA_1_1            6         1014              0.91917       701
# 1   AYA_1  AYA_1_10           10           98              0.08883       738
# 2   AYA_1   AYA_1_2            4         6677              6.05256       763
# 3   AYA_1   AYA_1_3            8          621              0.56292       762
# 4   AYA_1   AYA_1_4            9          364              0.32996       769
# 5   AYA_1   AYA_1_5            3        15289             13.85915       705
# 6   AYA_1   AYA_1_6            5         1250              1.13310       743
# 7   AYA_1   AYA_1_7            1        41081             37.23905       726
# 8   AYA_1   AYA_1_8            2        35676             32.33953       709
# 9   AYA_1   AYA_1_9            7          751              0.68077       719
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0         นายนเรศน์ ดาวเรือง          1              701
# ...

# %%
x1=Con_id1.merge(Candidate_constituancy, on='mp_app_id', how='left')
x1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# ##ตารางซ้าย.merge'columnที่เป็นคีย์เชื่อม'
# (ตารางซ้าย, left_on = 'columnที่เป็นคีย์เชื่อม')
# (ตารางขวา, right_on = 'columnที่เป็นคีย์เชื่อม')

# %% [markdown]
# ##วิธีลบคำซ้ำ

# %%
x1.merge(info_constituancy, on='cons_id',how='left')
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1   ACR_1_1            9          459              0.43477       706
# 2    ACR_1  ACR_1_10            1        38275             36.25419       709
# 3    ACR_1  ACR_1_10            1        38275             36.25419       709
# 4    ACR_1  ACR_1_11           13          126              0.11935       712
# 5    ACR_1  ACR_1_11           13          126              0.11935       712
# 6    ACR_1  ACR_1_12           12          127              0.12029       742
# 7    ACR_1  ACR_1_12           12          127              0.12029       742
# 8    ACR_1  ACR_1_13           11          212              0.20081       761
# 9    ACR_1  ACR_1_13           11          212              0.20081       761
# 10   ACR_1   ACR_1_2           10          234              0.22165       769
# ...

# %%
x2 = x1.merge(info_constituancy, on='cons_id',how='left')

# %%
x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
x3=x2[['cons_id','mp_app_id','party_id',	'mp_app_name','mp_app_vote',	'mp_app_vote_percent'	]]

# %%
x3
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 3    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 5    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 7    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 9    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 11   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# ...

# %%
# making a bool series
bool_series = x3.duplicated(subset='mp_app_name')
# passing NOT of bool series to see unique values only
x4 = x3[~bool_series]
# displaying data
x5 = x4.reset_index()
x5
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1       2   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2       4   ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 3       6   ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 4       8   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 5      10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 6      12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 9      18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 10     20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# ...

# %%
y ={
    'LOL' : ['sc','sa','si','gh','jk','lg','fg','jg','kn','lj','fd','ng']
}

# %%
lol =pd.DataFrame(y)
lol
# Out:
#    LOL
# 0   sc
# 1   sa
# 2   si
# 3   gh
# 4   jk
# 5   lg
# 6   fg
# 7   jg
# 8   kn
# 9   lj
# 10  fd
# 11  ng
